# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt # plotting
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# Loading the CSV file into a pandas dataframe.
#source: https://archive.ics.uci.edu/dataset/186/wine+quality
#df = pd.read_csv("winequality-red.csv",names=["fixed acidity","volatile acidity","citric acid","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density","pH","sulphates","alcohol","quality"],sep = ';',header=None)
df = pd.read_csv("winequality-red.csv")
# To peek at first five rows
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# # Data Analysis

# %%
# To identify the type of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Getting the number of instances and features
df.shape
# Out:
# (1599, 12)

# %%
# Getting the dimensions of the data frame
df.ndim
# Out:
# 2

# %%
# Finding the null values
print(df.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Descriptive Statistics
df.describe().transpose()
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
#check duplicated recotd
df.duplicated().sum()
# Out:
# 240

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (1359, 12)

# %%
#Descriptive Statistics
df.describe().transpose()
# Out:
#                        count       mean        std      min      25%      50%  \
# fixed acidity         1359.0   8.310596   1.736990  4.60000   7.1000   7.9000
# volatile acidity      1359.0   0.529478   0.183031  0.12000   0.3900   0.5200
# citric acid           1359.0   0.272333   0.195537  0.00000   0.0900   0.2600
# residual sugar        1359.0   2.523400   1.352314  0.90000   1.9000   2.2000
# chlorides             1359.0   0.088124   0.049377  0.01200   0.0700   0.0790
# free sulfur dioxide   1359.0  15.893304  10.447270  1.00000   7.0000  14.0000
# total sulfur dioxide  1359.0  46.825975  33.408946  6.00000  22.0000  38.0000
# density               1359.0   0.996709   0.001869  0.99007   0.9956   0.9967
# pH                    1359.0   3.309787   0.155036  2.74000   3.2100   3.3100
# sulphates             1359.0   0.658705   0.170667  0.33000   0.5500   0.6200
# alcohol               1359.0  10.432315   1.082065  8.40000   9.5000  10.2000
# quality               1359.0   5.623252   0.823578  3.00000   5.0000   6.0000
#
#                            75%        max
# fixed acidity          9.20000   15.90000
# volatile acidity       0.64000    1.58000
# citric acid            0.43000    1.00000
# residual sugar         2.60000   15.50000
# chlorides              0.09100    0.61100
# free sulfur dioxide   21.00000   72.00000
# total sulfur dioxide  63.00000  289.00000
# density                0.99782    1.00369
# pH                     3.40000    4.01000
# sulphates              0.73000    2.00000
# alcohol               11.10000   14.90000
# quality                6.00000    8.00000

# %%
df['quality'].value_counts().sort_index().plot.area(figsize=(16,8),title='Distribution of Red Wine Quality Ratingse',color='orange')
#our data set was unbalanced. Most of the quality values were 5 and 6
# Out:
# <Axes: title={'center': 'Distribution of Red Wine Quality Ratingse'}>

# %%
print(df['quality'].value_counts())
# Out:
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: quality, dtype: int64

# %%
# Plotting a Seaborn Correlation heat map
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),cmap="BrBG",annot=True)
# Out:
# <Axes: >

# %%
#Wine quality has the highest positive correlation with alcohol.
#Other relation degrees are very low with each other,such as fixed acidity, citric acid,residual sugar, free sulfur dioxide and pH.
#Quality also has negative correlation with variables such as volatile acidity, chlorides, total_sulfur_dioxide and density.
#Wine quality has the highest negative correlation with volatile acidity.
#we could remove some features however since in total we only have 11 variable, I prefer not to drop any columns.

# %%
#Check the outliers for each feature with respect to output value
fig, ax1  = plt.subplots(3,4,figsize = (10,6))
#fixed acidity does not give any specification to classify the quality.
sns.barplot(x = 'quality', y = 'fixed acidity', data = df, ax = ax1 [0][0])
#Reverse trend in the volatile acidity wrt the quality
sns.barplot(x = 'quality', y = 'volatile acidity', data = df, ax = ax1 [0][1])
#Citric acid goes higher as the quality of the wine goes higher
sns.barplot(x = 'quality', y = 'citric acid', data = df, ax = ax1 [0][2])
#residual sugar is irrelevant to the quality
sns.barplot(x = 'quality', y = 'residual sugar', data = df, ax = ax1 [0][3])
#Chloride goes down as the quality of the wine goes higher
sns.barplot(x = 'quality', y = 'chlorides', data = df, ax = ax1 [1][0])
#no direct relationship with free sulfur dioxide
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = df, ax = ax1 [1][1])
#no direct relationship with total sulfur dioxid
sns.barplot(x = 'quality', y = 'total sulfur dioxide', data = df, ax = ax1 [1][2])
#no direct relationship with density
sns.barplot(x = 'quality', y = 'density', data = df, ax = ax1 [1][3])
#PH decreases wrt to quality of wine
sns.barplot(x = 'quality', y = 'pH', data = df, ax = ax1 [2][0])
#Sulphates level goes higher with the quality of wine
sns.barplot(x = 'quality', y = 'sulphates', data = df, ax = ax1 [2][1])
#Alcohol level also goes higher as the quality of wine increases
sns.barplot(x = 'quality', y = 'alcohol', data = df, ax = ax1 [2][2])
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
#Dist plot of all features:
# create dist plot
#df.displot(figsize=(12,12))
#plt.show()
# create dist plot
import seaborn as sns
fig, ax = plt.subplots(ncols=4, nrows=3, figsize=(20,10))
index = 0
ax = ax.flatten()

for col, value in df.items():
    if col != 'type':
        sns.histplot(value, ax=ax[index], kde=True,
                     stat="density", kde_kws=dict(cut=3))
        index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
#Check the outliers for each feature

plt.figure(figsize=(20,15))
sns.boxplot(data=df)
plt.yticks(range(0,200,30))
plt.xticks(size=15, rotation=55)
plt.title('Data Distribution', size=20, y=1.02)
plt.show()

# %% [markdown]
# #Remove outliers

# %%
#there are some serious outliers in the residual sugar, free sulfur dioxide and total sulfur dioxide columns
#the raw data should be preprocessed for getting higher precision rates.
#according to my literature review, one prevalent approach involves employing the Interquartile Range (IQR), primarily suited for skewed datasets.
#another commonly used technique is the implementation of Standard Deviation, which is more applicable to datasets following a normal distribution.
#here i have detected outliers and any other abnormalities that are above three standard deviations from the mean of the column.
cols = ['residual sugar', 'free sulfur dioxide', 'total sulfur dioxide']

for c in cols:
    upper_level = df[c].mean() + 3*df[c].std()
    lower_level = df[c].mean() - 3*df[c].std()
    df = df[(df[c] > lower_level) & (df[c] < upper_level)]

# %%
#visualize some of the attrinutes the wine has and look for outliers
plt.figure(figsize=(20,15))
sns.boxplot(data=df)
plt.yticks(range(0,200,30))
plt.xticks(size=15, rotation=55)
plt.title('Data Distribution after outliers clean up', size=20, y=1.02)
plt.show()

# %% [markdown]
# # Testing with Decision Tree, Logistic Regression, and SVC technique

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#X = df.drop('quality', axis = 1)
# some features show almost no correlation with quality, so i choose to drop few
X = df.drop(['fixed acidity','residual sugar','free sulfur dioxide','quality',], axis = 1)
y = df['quality']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn import metrics
# Create Decision Tree classifer object
dt = DecisionTreeClassifier()
# Train Decision Tree Classifer
dt.fit(X_train,y_train)
#Predict the response for test dataset
y_pred = dt.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Macro-averaging F1:",metrics.f1_score(y_test, y_pred,average='macro'))
#print("Macro-Averaged Precision score:",metrics.precision_score(y_test,y_pred, average='macro'))
print("Macro-averaged recall score:",metrics.recall_score(y_test, y_pred, average='macro'))

# %%
from sklearn.linear_model import LogisticRegression
dt = LogisticRegression() #select the algorithm
dt.fit(X_train,y_train) # we fit the algorithm with the training data and the training output
#Predict the response for test dataset
y_pred = dt.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Macro-averaging F1:",metrics.f1_score(y_test, y_pred,average='macro'))
#print("Macro-Averaged Precision score:",metrics.precision_score(y_test,y_pred, average='macro'))
print("Macro-averaged recall score:",metrics.recall_score(y_test, y_pred, average='macro'))
print("Macro-averaged recall score:",metrics.precision_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy: 0.555984555984556
# Macro-averaging F1: 0.259767527971726
# Macro-averaged recall score: 0.2611968744044216
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-4f6e5a94b9f2> in <cell line: 11>()
#       9 #print("Macro-Averaged Precision score:",metrics.precision_score(y_test,y_pred, average='macro'))
#      10 print("Macro-averaged recall score:",metrics.recall_score(y_test, y_pred, average='macro'))
# ---> 11 print("Macro-averaged recall score:",metricsprecision_score(y_test, y_pred, average='macro'))
#
# NameError: name 'metricsprecision_score' is not defined

# %%
from sklearn.svm import SVC
dt = SVC()
dt.fit(X_train, y_train) #, sample_weight=sample_weight)
y_pred = dt.predict(X_test)
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Macro-averaging F1:",metrics.f1_score(y_test, y_pred,average='macro'))
#print("Macro-Averaged Precision score:",metrics.precision_score(y_test,y_pred, average='macro'))
print("Macro-averaged recall score:",metrics.recall_score(y_test, y_pred, average='macro'))
# Out:
# Accuracy: 0.5714285714285714
# Macro-averaging F1: 0.26978680361033297
# Macro-averaged recall score: 0.2674861825805222

# %% [markdown]
# #PyCaret library

# %%
#installing pycaret library
pip install pycaret --quiet

# %%
pip install pycaret[full] --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 87.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 54.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 17.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 86.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 kB 27.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 67.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 69.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 kB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.8/279.8 kB 27.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 65.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 63.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 67.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.6/409.6 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 37.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.5/357.5 kB 30.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.2/136.2 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 117.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.2/221.2 kB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.0/275.0 kB 28.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 kB 19.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 18.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 75.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.7/302.7 kB 34.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 70.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 64.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 62.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 67.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 20.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 65.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 62.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 64.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 52.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 43.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 66.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 29.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.0/758.0 kB 37.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 25.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 61.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 64.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 37.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 43.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 18.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 22.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 62.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 78.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 MB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 12.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.5/357.5 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.5/357.5 kB 28.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 43.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 24.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 103.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 64.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.6/981.6 kB 67.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 16.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.3/448.3 kB 43.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 26.4 MB/s eta 0:00:00
#   Building wheel for pyod (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for htmlmin (setup.py) ... done
#   Building wheel for fugue-sql-antlr (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for lime (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.50 which is incompatible.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.

# %%
# check installed version
import pycaret
pycaret.__version__
# Out:
# '3.2.0'

# %%
#the PyCaret classification module can be used for Binary or Multi-class classification problems.
#Build classifier model using pycaret
# ! pip install pycaret
from pycaret.classification import *

# %%
# import ClassificationExperiment and init the class
from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()
# init setup on exp
model = setup(data = df, target = 'quality', session_id = 123)
# Out:
# <style type="text/css">
# #T_3dd9a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3dd9a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3dd9a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3dd9a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3dd9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3dd9a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3dd9a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3dd9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3dd9a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3dd9a_row1_col1" class="data row1 col1" >quality</td>
#     </tr>
#     <tr>
#       <th id="T_3dd9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3dd9a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3dd9a_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_3dd9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3dd9a_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_3dd9a_row3_col1" class="data row3 col1" >3: 0, 4: 1, 5: 2, 6: 3, 7: 4, 8: 5</td>
#     </tr>
#     <tr>
#       <th id="T_
row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_7a470_row2_col1" class="data row2 col1" >0.5850</td>
#       <td id="T_7a470_row2_col2" class="data row2 col2" >0.5177</td>
#       <td id="T_7a470_row2_col3" class="data row2 col3" >0.5850</td>
#       <td id="T_7a470_row2_col4" class="data row2 col4" >0.5546</td>
#       <td id="T_7a470_row2_col5" class="data row2 col5" >0.5640</td>
#       <td id="T_7a470_row2_col6" class="data row2 col6" >0.3329</td>
#       <td id="T_7a470_row2_col7" class="data row2 col7" >0.3368</td>
#       <td id="T_7a470_row2_col8" class="data row2 col8" >10.1750</td>
#     </tr>
#     <tr>
#       <th id="T_7a470_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_7a470_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_7a470_row3_col1" class="data row3 col1" >0.5839</td>
#       <td id="T_7a470_row3_col2" class="data row3 col2" >0.5259</td>
#       <td id="T_7a470_row3_col3" class="data row3 col3" >0.5839</td>
#       <td id="T_7a470_row3_col4" class="data row3 col4" >0.5495</td>
#       <td id="T_7a470_row3_col5" class="data row3 col5" >0.5589</td>
#       <td id="T_7a470_row3_col6" class="data row3 col6" >0.3240</td>
#       <td id="T_7a470_row3_col7" class="data row3 col7" >0.3289</td>
#       <td id="T_7a470_row3_col8" class="data row3 col8" >0.3920</td>
#     </tr>
#     <tr>
#       <th id="T_7a470_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_7a470_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_7a470_row4_col1" class="data row4 col1" >0.5806</td>
#       <td id="T_7a470_row4_col2" class="data row4 col2" >0.5207</td>
#       <td id="T_7a470_row4_col3" class="data row4 col3" >0.5806</td>
#       <td id="T_7a470_row4_col4" class="data row4 col4" >0.5584</td>
#       <td id="T_7a470_row4_col5" class="data row4 col5" >0.5646</td>
#       <td id="T_7a470_row4_col6" class="data row4 col6" >0.3339</td>
#       <td id="T_7a470_row4_col7" class="data row4 col7" >0.3369</td>
#       <td id="T_7a470_row4_col8" class="data row4 col8" >2.4290</td>
#     </tr>
#     <tr>
#       <th id="T_7a470_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_7a470_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_7a470_row5_col1" class="data row5 col1" >0.5795</td>
#       <td id="T_7a470_row5_
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]

# %%
#Tune the parameters and check for the performance of each model
#When set normalize to True, it transforms the features by scaling them to a given range.
#when transformation is set to be true, it applies the power transform to make data more Gaussian-like.
model = setup(data=df, target='quality', session_id=123, normalize=True, transformation=True)
# Out:
# <style type="text/css">
# #T_99f72_row9_col1, #T_99f72_row13_col1, #T_99f72_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_99f72" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99f72_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_99f72_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99f72_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99f72_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_99f72_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99f72_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_99f72_row1_col1" class="data row1 col1" >quality</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99f72_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_99f72_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99f72_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_99f72_row3_col1" class="data row3 col1" >3: 0, 4: 1, 5: 2, 6: 3, 7: 4, 8: 5</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99f72_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_99f72_row4_col1" class="data row4 col1" >(1245, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99f72_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_99f72_row5_col1" class="data row5 col1" >(1245, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99f72_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_99f72_row6_col1" class="data row6 col1" >(871, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99f72_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_99f72_row7_col1" class="data row7 col1" >(374, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99f72_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_99f72_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99f72_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_99f72_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99f72_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_99f72_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99f72_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_99f72_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99f72_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_99f72_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99f72_row13_col0" class="data row13 col0" >Transformation</td>
#       <td id="T_99f72_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99f72_row14_col0" class="data row14 col0" >Transformation method</td>
#       <td id="T_99f72_row14_col1" class="data row14 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_99f72_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_99f72_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_99f72_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_99f72_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_99f72_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_99f72_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_99f72_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_99f72_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_99f72_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_99f72_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_99f72_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_99f72_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_99f72_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_99f72_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_99f72_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_99f72_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_99f72_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_99f72_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_99f72_row23_col1" class="data row23 col1" >c263</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_final = compare_models()
#Among several models, the Extra Trees Classifier emerged as the most effective,
#achieving a 59% accuracy rate in classifying wine quality on a scale of 0-10.
#Additionally, both the Random Forest Classifier and the CatBoost Classifier exhibited commendable accuracy in this classification project.
# Out:
# <style type="text/css">
# #T_0b74b th {
#   text-align: left;
# }
# #T_0b74b_row0_col0, #T_0b74b_row0_col2, #T_0b74b_row1_col0, #T_0b74b_row1_col1, #T_0b74b_row1_col2, #T_0b74b_row1_col3, #T_0b74b_row1_col4, #T_0b74b_row1_col5, #T_0b74b_row1_col6, #T_0b74b_row1_col7, #T_0b74b_row2_col0, #T_0b74b_row2_col1, #T_0b74b_row2_col2, #T_0b74b_row2_col3, #T_0b74b_row2_col4, #T_0b74b_row2_col5, #T_0b74b_row2_col6, #T_0b74b_row2_col7, #T_0b74b_row3_col0, #T_0b74b_row3_col1, #T_0b74b_row3_col2, #T_0b74b_row3_col3, #T_0b74b_row3_col4, #T_0b74b_row3_col5, #T_0b74b_row3_col6, #T_0b74b_row3_col7, #T_0b74b_row4_col0, #T_0b74b_row4_col1, #T_0b74b_row4_col2, #T_0b74b_row4_col3, #T_0b74b_row4_col4, #T_0b74b_row4_col5, #T_0b74b_row4_col6, #T_0b74b_row4_col7, #T_0b74b_row5_col0, #T_0b74b_row5_col1, #T_0b74b_row5_col2, #T_0b74b_row5_col3, #T_0b74b_row5_col4, #T_0b74b_row5_col5, #T_0b74b_row5_col6, #T_0b74b_row5_col7, #T_0b74b_row6_col0, #T_0b74b_row6_col1, #T_0b74b_row6_col2, #T_0b74b_row6_col3, #T_0b74b_row6_col4, #T_0b74b_row6_col5, #T_0b74b_row6_col6, #T_0b74b_row6_col7, #T_0b74b_row7_col0, #T_0b74b_row7_col1, #T_0b74b_row7_col2, #T_0b74b_row7_col3, #T_0b74b_row7_col4, #T_0b74b_row7_col5, #T_0b74b_row7_col6, #T_0b74b_row7_col7, #T_0b74b_row8_col0, #T_0b74b_row8_col1, #T_0b74b_row8_col3, #T_0b74b_row8_col4, #T_0b74b_row8_col5, #T_0b74b_row8_col6, #T_0b74b_row8_col7, #T_0b74b_row9_col0, #T_0b74b_row9_col1, #T_0b74b_row9_col2, #T_0b74b_row9_col3, #T_0b74b_row9_col4, #T_0b74b_row9_col5, #T_0b74b_row9_col6, #T_0b74b_row9_col7, #T_0b74b_row10_col0, #T_0b74b_row10_col1, #T_0b74b_row10_col2, #T_0b74b_row10_col3, #T_0b74b_row10_col4, #T_0b74b_row10_col5, #T_0b74b_row10_col6, #T_0b74b_row10_col7, #T_0b74b_row11_col0, #T_0b74b_row11_col1, #T_0b74b_row11_col2, #T_0b74b_row11_col3, #T_0b74b_row11_col4, #T_0b74b_row11_col5, #T_0b74b_row11_col6, #T_0b74b_row11_col7, #T_0b74b_row12_col0, #T_0b74b_row12_col1, #T_0b74b_row12_col2, #T_0b74b_row12_col3, #T_0b74b_row12_col4, #T_0b74b_row12_col5, #T_0b74b_row12_col6, #T_0b74b_row12_col7, #T_0b74b_row13_col0, #T_0b74b_row13_col1, #T_0b74b_row13_col2, #T_0b74b_row13_col3, #T_0b74b_row13_col4, #T_0b74b_row13_col5, #T_0b74b_row13_col6, #T_0b74b_row13_col7, #T_0b74b_row14_col0, #T_0b74b_row14_col1, #T_0b74b_row14_col2, #T_0b74b_row14_col3, #T_0b74b_row14_col4, #T_0b74b_row14_col5, #T_0b74b_row14_col6, #T_0b74b_row14_col7, #T_0b74b_row15_col0, #T_0b74b_row15_col1, #T_0b74b_row15_col2, #T_0b74b_row15_col3, #T_0b74b_row15_col4, #T_0b74b_row15_col5, #T_0b74b_row15_col6, #T_0b74b_row15_col7 {
#   text-align: left;
# }
# #T_0b74b_row0_col1, #T_0b74b_row0_col3, #T_0b74b_row0_col4, #T_0b74b_row0_col5, #T_0b74b_row0_col6, #T_0b74b_row0_col7, #T_0b74b_row8_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0b74b_row0_col8, #T_0b74b_row1_col8, #T_0b74b_row2_col8, #T_0b74b_row3_col8, #T_0b74b_row4_col8, #T_0b74b_row5_col8, #T_0b74b_row6_col8, #T_0b74b_row7_col8, #T_0b74b_row8_col8, #T_0b74b_row9_col8, #T_0b74b_row10_col8, #T_0b74b_row11_col8, #T_0b74b_row12_col8, #T_0b74b_row13_col8, #T_0b74b_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0b74b_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0b74b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b74b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0b74b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0b74b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0b74b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0b74b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0b74b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0b74b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0b74b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0b74b_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b74b_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_0b74b_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_0b74b_row0_col1" class="data row0 col1" >0.5924</td>
#       <td id="T_0b74b_row0_col2" class="data row0 col2" >0.4344</td>
#       <td id="T_0b74b_row0_col3" class="data row0 col3" >0.5924</td>
#       <td id="T_0b74b_row0_col4" class="data row0 col4" >0.5657</td>
#       <td id="T_0b74b_row0_col5" class="data row0 col5" >0.5740</td>
#       <td id="T_0b74b_row0_col6" class="data row0 col6" >0.3441</td>
#       <td id="T_0b74b_row0_col7" class="data row0 col7" >0.3477</td>
#       <td id="T_0b74b_row0_col8" class="data row0 col8" >7.1440</td>
#     </tr>
#     <tr>
#       <th id="T_0b74b_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_0b74b_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_0b74b_row1_col1" class="data row1 col1" >0.5901</td>
#       <td id="T_0b74b_row1_col2" class="data row1 col2" >0.4308</td>
#       <td id="T_0b74b_row1_col3" class="data row1 col3" >0.5901</td>
#       <td id="T_0b74b_row1_col4" class="data row1 col4" >0.5618</td>
#       <td id="T_0b74b_row1_col5" class="data row1 col5" >0.5652</td>
#       <td id="T_0b74b_row1_col6" class="data row1 col6" >0.3298</td>
#       <td id="T_0b74b_row1_col7" class="data row1 col7" >0.3352</td>
#       <td id="T_0b74b_row1_col8" class="data row1 col8" >0.5470</td>
#     </tr>
#     <tr>
#       <th id="T_0b74b_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_0b74b_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_0b74b_row2_col1" class="data row2 col1" >0.5867</td>
#       <td id="T_0b74b_row2_col2" class="data row2 col2" >0.4380</td>
#       <td id="T_0b74b_row2_col3" class="data row2 col3" >0.5867</td>
#       <td id="T_0b74b_row2_col4" class="data row2 col4" >0.5571</td>
#       <td id="T_0b74b_row2_col5" class="data row2 col5" >0.5635</td>
#       <td id="T_0b74b_row2_col6" class="data row2 col6" >0.3251</td>
#       <td id="T_0b74b_row2_col7" class="data row2 col7" >0.3294</td>
#       <td id="T_0b74b_row2_col8" class="data row2 col8" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_0b74b_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_0b74b_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_0b74b_row3_col1" class="data row3 col1" >0.5855</td>
#       <td id="T_0b74b_row3_col2" class="data row3 col2" >0.4322</td>
#       <td id="T_0b74b_row3_col3" class="data row3 col3" >0.5855</td>
#       <td id="T_0b74b_row3_col4" class="data row3 col4" >0.5654</td>
#       <td id="T_0b74b_row3_col5" class="data row3 col5" >0.5625</td>
#       <td id="T_0b74b_row3_col6" class="data row3 col6" >0.3254</td>
#       <td id="T_0b74b_row3_col7" class="data row3 col7" >0.3326</td>
#       <td id="T_0b74b_row3_col8" class="data row3 col8" >0.2850</td>
#     </tr>
#     <tr>
#       <th id="T_0b74b_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_0b74b_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0b74b_row4_col1" class="data row4 col1" >0.5810</td>
#       <td id="T_0b74b_row4_col2" class="data row4 col2" >0.4294</td>
#       <td id="T_0b74b_row4_col3" class="data row4 col3" >0.5810</td>
#       <td id="T_0b74b_row4_col4" class="data row4 col4" >0.5578</td>
#       <td id="T_0b74b_row4_col5" class="data row4 col5" >0.5627</td>
#       <td id="T_0b74b_row4_col6" class="data row4 col6" >0.3262</td>
#       <td id="T_0b74b_row4_col7" class="data row4 col7" >0.3309</td>
#       <td id="T_0b74b_row4_col8" class="data row4 col8" >4.4350</td>
#     </tr>
#     <tr>
#       <th id="T_0b74b_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_0b74b_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_0b74b_row5_col1" class="data row5 col1" >0.5797</td>
#       <td id="T_0b74b_row5_col
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]

# %%
# save experiment
save_experiment('my_experiment')
# load experiment from disk
exp_from_disk = load_experiment('my_experiment', data=df)
# Out:
# <style type="text/css">
# #T_e1e84_row9_col1, #T_e1e84_row13_col1, #T_e1e84_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e1e84" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1e84_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e1e84_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1e84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1e84_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e1e84_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1e84_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e1e84_row1_col1" class="data row1 col1" >quality</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1e84_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e1e84_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1e84_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_e1e84_row3_col1" class="data row3 col1" >3: 0, 4: 1, 5: 2, 6: 3, 7: 4, 8: 5</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1e84_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_e1e84_row4_col1" class="data row4 col1" >(1245, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e1e84_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_e1e84_row5_col1" class="data row5 col1" >(1245, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e1e84_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_e1e84_row6_col1" class="data row6 col1" >(871, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e1e84_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_e1e84_row7_col1" class="data row7 col1" >(374, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e1e84_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_e1e84_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e1e84_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_e1e84_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e1e84_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_e1e84_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e1e84_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_e1e84_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e1e84_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_e1e84_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e1e84_row13_col0" class="data row13 col0" >Transformation</td>
#       <td id="T_e1e84_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e1e84_row14_col0" class="data row14 col0" >Transformation method</td>
#       <td id="T_e1e84_row14_col1" class="data row14 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e1e84_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_e1e84_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e1e84_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_e1e84_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e1e84_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_e1e84_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e1e84_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_e1e84_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e1e84_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_e1e84_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e1e84_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_e1e84_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e1e84_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_e1e84_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e1e84_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_e1e84_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e1e84_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e1e84_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_e1e84_row23_col1" class="data row23 col1" >16c1</td>
#     </tr>
#   </tbody>
# </table>
